# %%
# %cd ./yolov9

# !python train.py \
--batch 16 --epochs 500 --img 640 --device 4 --min-items 0 --close-mosaic 15 \
--data  /home/tyfei/datasets/cyroem/test1/test_data_ribo/yolo/data.yaml\
--weights /home/tyfei/cyroem/checkpoints/yolov9/gelan-c.pt \
--cfg /home/tyfei/cyroem/yolov9/models/detect/gelan-c.yaml \
--hyp hyp.scratch-high.yaml
# Out:
# train: weights=/home/tyfei/cyroem/checkpoints/yolov9/gelan-c.pt, cfg=/home/tyfei/cyroem/yolov9/models/detect/gelan-c.yaml, data=/home/tyfei/datasets/cyroem/test1/test_data_ribo/yolo/data.yaml, hyp=hyp.scratch-high.yaml, epochs=500, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=4, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, flat_cos_lr=False, fixed_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, min_items=0, close_mosaic=15, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# YOLOv5 🚀 1e33dbb Python-3.12.2 torch-2.2.2 CUDA:4 (NVIDIA GeForce RTX 4090, 24217MiB)
#
# ...

# %%
# !python detect.py --weights /home/tyfei/cyroem/yolov9/runs/train/exp9/weights/best.pt --conf 0.1 --source /home/tyfei/datasets/cyroem/test1/test_data_ribo/yolo/images/val/TS_036_137.jpeg --device 4
# Out:
# detect: weights=['/home/tyfei/cyroem/yolov9/runs/train/exp9/weights/best.pt'], source=/home/tyfei/datasets/cyroem/test1/test_data_ribo/yolo/images/val/TS_036_137.jpeg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=4, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.12.2 torch-2.2.2 CUDA:4 (NVIDIA GeForce RTX 4090, 24217MiB)
#
# Fusing layers...
# gelan-c summary: 467 layers, 25411731 parameters, 0 gradients, 102.5 GFLOPs
# image 1/1 /home/tyfei/datasets/cyroem/test1/test_data_ribo/yolo/images/val/TS_036_137.jpeg: 640x480 9 ribos, 149.8ms
# Speed: 0.4ms pre-process, 149.8ms inference, 74.3ms NMS per image at shape (1, 3, 640, 640)
# ...

# %%
#106， 137
